# %%
#Mini Project( Student Management System)
students = []
def add_student():
    name = input("Enter student name: ")
    marks = []
    for i in range(3):
        mark = float(input(f"Enter marks for subject {i + 1}: "))
        marks.append(mark)
    student = {
        "name": name,
        "marks": marks
    }
    students.append(student)
    print("Student added successfully!")
    
def calculate_average(marks):
    return sum(marks) / len(marks)

def display_students():
    if not students:
        print("No students available.")
        return
    print("\n--- Student Information ---")
    for student in students:
        average = calculate_average(student["marks"])
        print(f"\nName: {student['name']}")
        print(f"Marks: {student['marks']}")
        print(f"Average: {average:.2f}")

def find_highest_scorer():
    if not students:
        print("No students available.")
        return
    highest_student = students[0]
    for student in students:
        current_average = calculate_average(student["marks"])
        highest_average = calculate_average(highest_student["marks"])
        if current_average > highest_average:
            highest_student = student
    average = calculate_average(highest_student["marks"])
    print("\n--- Highest Scorer ---")
    print("Name:", highest_student["name"])
    print("Marks:", highest_student["marks"])
    print("Average:", round(average, 2))
    
def search_student():
    name = input("Enter student name to search: ")
    for student in students:
        if student["name"].lower() == name.lower():
            average = calculate_average(student["marks"])

            print("\nStudent Found!")
            print("Name:", student["name"])
            print("Marks:", student["marks"])
            print("Average:", round(average, 2))
            return
    print("Student not found.")

while True:
    print("\n===== Student Management System =====")
    print("1. Add Student")
    print("2. Display Students")
    print("3. Find Highest Scorer")
    print("4. Search Student")
    print("5. Exit")
    choice = input("Enter your choice: ")
    if choice == "1":
        add_student()
    elif choice == "2":
        display_students()
    elif choice == "3":
        find_highest_scorer()
    elif choice == "4":
        search_student()
    elif choice == "5":
        print("Program ended.")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# ===== Student Management System =====
# 1. Add Student
# 2. Display Students
# 3. Find Highest Scorer
# 4. Search Student
# 5. Exit
# Enter your choice:  1
# Enter student name:  Sarita Shrestha
# Enter marks for subject 1:  89
# Enter marks for subject 2:  78
# Enter marks for subject 3:  88
# Student added successfully!
#
# ===== Student Management System =====
# 1. Add Student
# 2. Display Students
# 3. Find Highest Scorer
# 4. Search Student
# 5. Exit
# Enter your choice:  1
# Enter student name:  Saru Thapa
# Enter marks for subject 1:  89
# Enter marks for subject 2:  67
# Enter marks for subject 3:  98
# Student added successfully!
#
# ===== Student Management System =====
# 1. Add Student
# 2. Display Students
# 3. Find Highest Scorer
# 4. Search Student
# 5. Exit
# Enter your choice:  2
# --- Student Information ---
#
# Name: Sarita Shrestha
# Marks: [89.0, 78.0, 88.0]
# Average: 85.00
#
# Name: Saru Thapa
# Marks: [89.0, 67.0, 98.0]
# Average: 84.67
#
# ===== Student Management System =====
# 1. Add Student
# 2. Display Students
# 3. Find Highest Scorer
# 4. Search Student
# 5. Exit
# Enter your choice:  3
# --- Highest Scorer ---
# Name: Sarita Shrestha
# Marks: [89.0, 78.0, 88.0]
# Average: 85.0
#
# ===== Student Management System =====
# 1. Add Student
# 2. Display Students
# 3. Find Highest Scorer
# 4. Search Student
# 5. Exit
# Enter your choice:  4
# Enter student name to search:  Saru Thapa
# Student Found!
# Name: Saru Thapa
# Marks: [89.0, 67.0, 98.0]
# Average: 84.67
#
# ===== Student Management System =====
# 1. Add Student
# 2. Display Students
# 3. Find Highest Scorer
# 4. Search Student
# 5. Exit
# Enter your choice:  5
# Program ended.
