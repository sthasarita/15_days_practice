# %%
#Number Guessing Game
import random
secret_number = random.randint(1, 100)
print(secret_number)
while True:
    guess = int(input("Guess the number (1-100):"))
    if guess < secret_number:
        print("Too low!")
    elif guess > secret_number:
        print("Too high!")
    else:
        print("Congratulations! You guessed it.")
        break
# Out:
# 14
# Guess the number (1-100): 14
# Congratulations! You guessed it.

# %%
# Multiplication Table Generator
num = int(input("Enter a number:"))
for i in range(1,11):
    print(f"{num} X {i} = {num * i}")
# Out:
# Enter a number: 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
# Prime-Number Checker
num = int(input("Enter a number:"))
if num <=1:
    print("Not a prime number.")
else:
    is_prime = True
    for i in range(2,num):
        if num % i == 0:
            is_prime = False
            break
    if is_prime:
        print("Prime number.")
    else:
        print("Not a prime number.")
# Out:
# Enter a number: 5
# Prime number.

# %%
# Factorial Program
num = int(input("Enter a number:"))
factorial = 1
for i in range(1,num+1):
    factorial = factorial * i
print(f"Factorial = {factorial}")
# Out:
# Enter a number: 4
# Factorial = 24

# %%
# Fibonacci Sequence
n = int(input("How many terms do you want?"))
a = 0
b = 1
for i in range(n):
    print(a, end = " ")
    a,b = b, a + b
# Out:
# How many terms do you want? 4
# 0 1 1 2

# %%
# Password Validation Program
choice = "y"
while choice == "y":
    password = input("Enter your password:")
    has_digit = False
    has_upper = False
    has_lower = False
    for char in password:
        if char.isdigit():
            has_digit = True
        if char.isupper():
            has_upper = True
        if char.islower():
            has_lower = True
    if len(password) >= 8 and has_digit and has_upper and has_lower:
        print("Valid Password.")
    else:
        print("Invalid Password.")
        if len(password) < 8:
            print("- Password must contain at least 8 characters.")
        if not has_digit:
            print("- Password must contain at least one digit.")
        if not has_upper:
            print("- Password must contain at least one uppercase letter.")
        if not has_lower:
            print("- Password must contain at least one lowercase letter.")
    choice = input("Again, you want to enter password:(y,n)")
# Out:
# Enter your password: shrstha123S
# Valid Password.
# Again, you want to enter password:(y,n) y
# Enter your password: shrestha123
# Invalid Password.
# - Password must contain at least one uppercase letter.
# Again, you want to enter password:(y,n) y
# Enter your password: SHRESTH123
# Invalid Password.
# - Password must contain at least one lowercase letter.
# Again, you want to enter password:(y,n) n
