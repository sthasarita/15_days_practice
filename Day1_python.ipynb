# %%
# Create a Calculator
num1 = float(input("Enter first number:"))
operator = input("Enter operator(+, -, *, /):")
num2 = float(input("Enter second number:"))

if operator == "+":
    print("Result", num1+num2)

elif operator == "-":
    print("Result", num1-num2)
elif operator == "*":
    print("Result", num1*num2)
elif operator == "/":
    if num2 != 0:
        print("Result", num1/num2)
    else:
        print("Can't divide by zero.")
else:
    print("Invalid operator.")
# Out:
# Enter first number: 4
# Enter operator(+, -, *, /): +
# Enter second number: 8
# Result 12.0

# %%
# Check Whether a Number Is Even or Odd
num = int(input("Enter a number:"))
if num %2 == 0:
    print(f"{num} is even.")
else:
    print(f"{num} is odd.")
# Out:
# Enter a number: 2
# 2 is even.

# %%
# Convert Celsius to Fahrenheit
celsius = float(input("Enter temperature in Celsius:"))
fahrenheit = (celsius * 9/5 ) + 32
print(f"Temperature in Fahrenheit = {fahrenheit}")
# Out:
# Enter temperature in Celsius: 0
# Temperature in Fahrenheit = 32.0

# %%
# Count Characters in a String
text = input("Enter a string:")
count = 0
for i in text:
    count += 1

print(f"Total characters = {count}")
# Out:
# Enter a string: sarita shrestha
# Total characters = 15

# %%
# Reverse a String
text = input("Enter a string:")
rev_text = text[::-1]
print(f"Reversed Text = {rev_text}")
# Out:
# Enter a string: sarita shrestha
# Reversed Text = ahtserhs atiras

# %%
# Simple Student-Information Program
name = input("Enter student name:")
age = int(input("Enter age:"))
address = input("Enter address:")
faculty = input("Enter faculty:")
semester = int(input("Enter semester:"))
gpa = float(input("Enter GPA: "))

print("\n ---Student Information---")
print("Name = ", name)
print("Age = ", age)
print("Address = ", address)
print("Faculty = ", faculty)
print("Semester = ", semester)
print("GPA = ", gpa)
# Out:
# Enter student name: Sarita Shrestha
# Enter age: 20
# Enter address: Imadole
# Enter faculty: CSIT
# Enter semester: 4
# Enter GPA:  3.6
#  ---Student Information---
# Name =  Sarita Shrestha
# Age =  20
# Address =  Imadole
# Faculty =  CSIT
# Semester =  4
# GPA =  3.6
