# %%
# Email Validation
import re
email = input("Enter email: ")
pattern = r"^[\w.-]+@[\w.-]+\.\w+$"
if re.match(pattern, email):
    print("Valid email")
else:
    print("Invalid email")
# Out:
# Enter email:  shresthasarita28913@gmail.com
# Valid email

# %%
# Phone Number Validation
import re
phone = input("Enter phone number: ")
pattern = r"^\d{10}$"
if re.match(pattern, phone):
    print("Valid phone number")
else:
    print("Invalid phone number")
# Out:
# Enter phone number:  9777777777
# Valid phone number

# %%
# Password Validation
import re
password = input("Enter password: ")
pattern = r"^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[@#$%^&*!]).{8,}$"
if re.match(pattern, password):
    print("Valid password")
else:
    print("Invalid password")
# Out:
# Enter password:  Python@123
# Valid password

# %%
# URL Extractio
text = """
Visit https://www.google.com
or https://www.python.org
for more information.
"""
import re
pattern = r"https?://[^\s]+"
urls = re.findall(pattern, text)
print(urls)
# Out:
# ['https://www.google.com', 'https://www.python.org']

# %%
# Finding Hashtags
import re
text = """
I am learning #Python and #DataScience.
#Programming is fun!
"""
hashtags = re.findall(r"#\w+", text)
print(hashtags)
# Out:
# ['#Python', '#DataScience', '#Programming']

# %%
# Extracting Numbers
import re
text = """
I bought 5 apples,
10 oranges and 25 bananas.
"""
numbers = re.findall(r"\d+", text)
print(numbers)
# Out:
# ['5', '10', '25']
